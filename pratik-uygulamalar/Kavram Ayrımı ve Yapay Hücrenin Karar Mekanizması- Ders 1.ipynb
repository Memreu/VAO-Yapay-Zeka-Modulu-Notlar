# %% [markdown]
# # 🧠 Ders 1 Uygulaması: Yapay Hücrenin (Perceptron) Karar Mekanizması
#
# Bu proje, Ders 1 notlarında işlediğimiz **Yapay Sinir Ağları (YSA)** ve **Geri Yayılım (Backpropagation)** konularının en temel yapı taşı olan tekil bir nöronun Python ile canlandırılmış halidir.
#
#
#
# ###  Karar Nasıl Verilir? (Neden 0 veya 1?)
# Hücremiz kararlarını ders notlarında belirtilen matematiksel modele göre üç aşamayla verir :
#
# 1.  **Sinyal Toplama**: Gelen her bir bilgi (girdi), kendi önem derecesiyle (ağırlık/weight) çarpılır ve toplanır.
# 2.  **Eşik Kontrolü**: Elde edilen toplam "sinyal gücü", aktivasyon fonksiyonundan ($f$) geçirilir.
# 3.  **Ateşleme (0 vs 1)**:
#     * Eğer sinyal gücü **0'dan büyükse**: Hücre uyarılır ve sonuç **1 (Ateşlendi)** olur.
#     * Eğer sinyal gücü **negatifse**: Hücre tepki vermez ve sonuç **0 (Sessiz Kaldı)** olur.
#
# ###  Öğrenme (Learning) Nedir?
# Başlangıçta ağırlıklar rastgele veya sıfır olduğu için hücre sürekli yanlış kararlar verir. Ancak her hatasında şu süreci izler:
#
# * **Hata Hesaplama**: Olması gereken gerçek değer ile kendi tahmini arasındaki farkı bulur.
# * **Geri Yayılım (Backpropagation)**: Bu hatayı geriye doğru ileterek ağırlıklarını ($a_1, a_2, \dots$) günceller.
# * **Genelleme**: Birkaç turun sonunda ağırlıklar öyle bir noktaya gelir ki, hücre artık daha önce görmediği durumlarda bile doğru kararı vermeye başlar.
#
# ###  Proje Bağlantısı
# Bu uygulama, 1957 yılında geliştirilen ilk yapay zeka programlarından biri olan **Perceptron**'u simüle eder. Günümüzün devasa GPT modellerinin temelinde yatan o meşhur **"Geri Yayılım" (1986)** algoritmasının en saf ve anlaşılır halidir.

# %%
import numpy as np

# --- DERS 1: YAPAY SİNİR HÜCRESİ (PERCEPTRON) SİMÜLASYONU ---

# 1. ADIM: AKTİVASYON FONKSİYONU
# Notlardaki 'f' fonksiyonu. Gelen sinyal 0'dan büyükse 1 (ateşle), değilse 0 (sus)[cite: 173].
def aktivasyon_f(x):
    return 1 if x >= 0 else 0

# 2. ADIM: EĞİTİM VERİLERİ (Mantıksal 'VE' Kapısı)
# İki girdi (x1, x2) ve beklenen doğru sonuç (y_dogru).
# Sadece iki girdi de 1 ise sonuç 1 olmalı.
egitim_verisi = [
    (np.array([1, 1]), 1),
    (np.array([1, 0]), 0),
    (np.array([0, 1]), 0),
    (np.array([0, 0]), 0),
]

# 3. ADIM: BAŞLANGIÇ AYARLARI
# Ağırlıklar (a1, a2) ve bias başlangıçta tamamen rastgele[cite: 168, 169].
weights = np.array([0.0, 0.0])
bias = 0.0
ogrenme_hizi = 0.1 # Hatadan ne kadar ders çıkaracak?

print("--- Yapay Hücre Eğitimi Başlıyor ---")

# 4. ADIM: ÖĞRENME DÖNGÜSÜ (Geri Yayılım Mantığı) [cite: 181, 182, 194]
for epoch in range(20): 
    toplam_hata = 0
    for x, y_dogru in egitim_verisi:
        # İleri Besleme: y = f(a1*x1 + a2*x2 + bias) [cite: 175, 197]
        toplam_sinyal = np.dot(x, weights) + bias
        tahmin = aktivasyon_f(toplam_sinyal)
        
        # Hata Hesaplama: Beklenen vs Tahmin edilen [cite: 201]
        hata = y_dogru - tahmin
        toplam_hata += abs(hata)
        
        # Geri Yayılım: Ağırlıkları Güncelleme [cite: 205, 206]
        # Hata varsa, ağırlıkları hatayı küçültecek yönde düzeltiyoruz.
        weights += ogrenme_hizi * hata * x
        bias += ogrenme_hizi * hata
        
    if toplam_hata == 0:
        print(f"Tur {epoch+1}: Harika! Hücre kuralı tamamen öğrendi.")
        break
    else:
        print(f"Tur {epoch+1}: Hala öğreniyor... Toplam hata: {toplam_hata}")

# 5. ADIM: TEST AŞAMASI
print("\n--- Eğitim Bitti, Hadi Hücreyi Test Edelim ---")
for x, _ in egitim_verisi:
    sonuc = aktivasyon_f(np.dot(x, weights) + bias)
    print(f"Girdi: {x} -> Karar: {sonuc}")
# Out:
# --- Yapay Hücre Eğitimi Başlıyor ---
# Tur 1: Hala öğreniyor... Toplam hata: 1
# Tur 2: Hala öğreniyor... Toplam hata: 3
# Tur 3: Hala öğreniyor... Toplam hata: 2
# Tur 4: Hala öğreniyor... Toplam hata: 2
# Tur 5: Hala öğreniyor... Toplam hata: 3
# Tur 6: Hala öğreniyor... Toplam hata: 1
# Tur 7: Harika! Hücre kuralı tamamen öğrendi.
#
# --- Eğitim Bitti, Hadi Hücreyi Test Edelim ---
# Girdi: [1 1] -> Karar: 1
# Girdi: [1 0] -> Karar: 0
# Girdi: [0 1] -> Karar: 0
# Girdi: [0 0] -> Karar: 0

# %% [markdown]
# Örneğin bir miktar detaylandırılmış hali alttadır.

# %%
import numpy as np

# --- 1. ADIM: KARAR MEKANIZMASI (AKTIVASYON FONKSIYONU) ---
# Sinyal gücü 0 veya daha büyükse hücre 1 (Ateşlendi) değerini üretir.
# Sinyal gücü negatifse hücre 0 (Sessiz) değerini üretir.
def aktivasyon_f(toplam_sinyal):
    if toplam_sinyal >= 0:
        return 1, "Pozitif Sinyal -> HÜCRE ATEŞLENDİ (1)"
    else:
        return 0, "Negatif Sinyal -> HÜCRE SESSİZ (0)"

# --- 2. ADIM: EĞITIM VERILERI (VE MANTIK KAPISI) ---
# [Girdi 1, Girdi 2] -> Beklenen Doğru Sonuç
egitim_verisi = [
    (np.array([1, 1]), 1),
    (np.array([1, 0]), 0),
    (np.array([0, 1]), 0),
    (np.array([0, 0]), 0),
]

# --- 3. ADIM: BAŞLANGIÇ PARAMETRELERI ---
# Ağırlıklar (weights) başlangıçta sıfırdır; yani sistem henüz cahildir.
weights = np.array([0.0, 0.0]) 
bias = 0.0          # Karar eşiği
ogrenme_hizi = 0.1  # Hatalardan ders çıkarma katsayısı

print("-" * 60)
print("YAPAY HÜCRE EĞITIM SÜRECI BAŞLIYOR")
print("-" * 60)

# --- 4. ADIM: EĞITIM DÖNGÜSÜ (BACKPROPAGATION) ---
# Sistem hata yaptıkça ağırlıklarını güncelleyerek kuralı öğrenmeye çalışır.
for epoch in range(15): 
    hata_yapildi_mi = False
    print(f"\nTUR (EPOCH) {epoch+1}")
    
    for x, hedef in egitim_verisi:
        # Matematiksel işlem: (x1 * w1) + (x2 * w2) + bias
        sinyal = np.dot(x, weights) + bias
        tahmin, aciklama = aktivasyon_f(sinyal)
        
        # Hata Kontrolü ve Geri Yayılım (Ağırlık Güncelleme)
        if tahmin != hedef:
            hata_yapildi_mi = True
            eski_weights = weights.copy()
            
            # Formül: Yeni Ağırlık = Eski Ağırlık + (Öğrenme Hızı * Hata * Girdi)
            fark = hedef - tahmin
            weights += ogrenme_hizi * fark * x
            bias += ogrenme_hizi * fark
            
            print(f"DURUM: Girdi {x} için Hedef {hedef} / Tahmin {tahmin} (Hatalı)")
            print(f"BILGI: Ağırlıklar güncellendi: {eski_weights} ===> {weights}")
        else:
            print(f"DURUM: Girdi {x} için Tahmin {tahmin} (Doğru) - {aciklama}")

    if not hata_yapildi_mi:
        print("\nSONUÇ: Tüm ihtimaller doğru öğrenildi. Eğitim başarılı.")
        break

# --- 5. ADIM: FINAL ANALIZI ---
print("\n" + "-" * 60)
print("EĞITIM SONU ANALIZ RAPORU")
print("-" * 60)
print(f"Öğrenilen Final Ağırlıkları: {weights}")
print(f"Öğrenilen Final Bias: {bias}")
print("\nAnaliz: Hücre artık girdilere bakıp aradaki f(x) kuralını çözdü.")
print("Bu sistem artık düşünmüyor, sadece istatistiksel bir tahmin yapıyor.")

# %% [markdown]
# ## 🧠 Ders 1 Uygulaması: Uzman Sistemler vs. Makine Öğrenmesi
#
# Ders 1 notlarında gördüğümüz "Yapay Zeka" ekosistemindeki o keskin ayrımı anlamak için bu interaktif aracı hazırladık. Her akıllı görünen sistem "öğrenen" bir sistem değildir.
#
# ### 🔍 Temel Farklar
# * **Uzman Sistemler:** İnsan uzmanların tecrübelerini "Eğer-O zaman" kuralları olarak sisteme işlemesiyle çalışır. Veriden kural çıkarmaz, sadece kendisine verilen kuralları sadık bir şekilde uygular.
# * **Makine Öğrenmesi:** İnsanlar kural yazmaz. Sisteme girdi (X) ve doğru çıktı (Y) verilir; algoritma bu ikisi arasındaki gizli ilişkiyi (f(x) fonksiyonunu) kendi keşfeder.
#
# ### 🛠️ Proje İçeriği
# Bu uygulama; tıp, finans ve mühendislik gibi 10 farklı alanda "Kural Tabanlı" ve "Veri Tabanlı" yaklaşımların nasıl ayrıştığını gösterir. Günümüzdeki çoğu sistemin aslında "Bilinçli Zeka" değil, "Başarılı İstatistiksel Tahmin Motorları" olduğu gerçeğini somutlaştırır.

# %%
import time

def karsilastir(olay_no):
    # Olay havuzumuz: Kuralı insan mı yazıyor yoksa makine mi keşfediyor?
    olaylar = {
        1: ("Kredi Onayı", "Banka müdürünün 'Maaş > 10k ise onayla' kuralı.", "Binlerce eski müşterinin ödemelerinden risk tahmini yapmak."),
        2: ("Hastalık Teşhisi", "Doktorun 'Ateş > 38 ise enfeksiyon' kılavuzu.", "Röntgen piksellerinden tümör olasılığını hesaplamak."),
        3: ("Satranç Hamlesi", "Şah tehdit altındaysa 'kaç' komutu.", "Milyonlarca maçtan elde edilen sezgisel strateji."),
        4: ("E-posta Filtresi", "'Bedava' kelimesi geçiyorsa spama at kuralı.", "Kelimelerin diziliminden spam ihtimalini bulmak."),
        5: ("Otonom Sürüş", "Kırmızı ışıkta 'dur' komutu.", "Sensörlerden gelen verilerle yayaların hamlesini öngörmek."),
        6: ("Hava Durumu", "Nem %90 ise 'yağmur yağar' kuralı.", "50 yıllık hava haritalarından örüntü çıkarmak."),
        7: ("Müşteri Desteği", "Soru 'İade' içeriyorsa ilgili birime bağla.", "Müşterinin ses tonundan modunu anlayıp ona göre konuşmak."),
        8: ("Çeviri", "Sözlükteki kelime karşılıklarını eşleştirmek.", "Cümledeki bağlamdan kelimenin gerçek anlamını çözmek."),
        9: ("Yatırım Analizi", "Dolar 30'u geçerse 'sat' kuralı.", "Piyasa haberlerinden yarınki borsa yönünü kestirmek."),
        10: ("Yüz Tanıma", "İki göz arası mesafeyi ölçen kural seti.", "Yüzdeki binlerce noktadan olasılıksal eşleştirme yapmak.")
    }

    secilen = olaylar[olay_no]
    print(f"\n📢 OLAY: {secilen[0]}")
    print("-" * 50)
    
    print("🧠 UZMAN SİSTEM YAKLAŞIMI (Kural Tabanlı):")
    print(f"   -> {secilen[1]}")
    print("   *Mekanizma: İnsan kuralı yazar, makine uygular. Kendi kendine öğrenmez.*")
    
    time.sleep(0.8) 
    
    print("\n🤖 MAKİNE ÖĞRENMESİ YAKLAŞIMI (Veri Tabanlı):")
    print(f"   -> {secilen[2]}")
    print("   *Mekanizma: Makine veriye bakar, f(x) kuralını kendi keşfeder.*")
    print("-" * 50)

# Ana Menü
while True:
    print("\n--- Uzman Sistem mi, Makine Öğrenmesi mi? (Ders 1) ---")
    print("1-Kredi, 2-Tıp, 3-Satranç, 4-Spam, 5-Araba, 6-Hava, 7-Destek, 8-Çeviri, 9-Borsa, 10-Yüz")
    try:
        secim = int(input("Bir olay seçin (Çıkış için 0): "))
        if secim == 0: break
        if 1 <= secim <= 10:
            karsilastir(secim)
        else:
            print("Lütfen 1-10 arası bir sayı seçin.")
    except ValueError:
        print("Geçersiz giriş!")

# %%
import numpy as np

# --- DERS 1: YAPAY SİNİR HÜCRESİ (PERCEPTRON) SİMÜLASYONU ---

# ❓ NEYE GÖRE 0, NEYE GÖRE 1? (Aktivasyon Fonksiyonu)
# Ders 1 notlarında gördüğümüz 'f' fonksiyonu burasıdır.
# Mantık çok basit: Hücreye gelen toplam sinyal gücü 0 veya daha büyükse, 
# hücre "tamam, bu önemli bir bilgi" der ve 1 (Ateşleme) sinyali üretir.
# Eğer sinyal gücü negatif kalırsa, "bu bilgi önemsiz" der ve 0 (Sessiz) kalır[cite: 173, 175].
def aktivasyon_f(sinyal_gucu):
    return 1 if sinyal_gucu >= 0 else 0

# --- 1. DERS NOTLARINA GÖRE VERİ SETİMİZ ---
# İki adet girdi (x1, x2) ve ulaşmak istediğimiz hedef çıktı (y_dogru).
# "VE" (AND) mantığını öğreteceğiz: Sadece ikisi de 1 ise sonuç 1 olmalı.
egitim_verisi = [
    (np.array([1, 1]), 1), # Girdi: [1, 1] -> Hedef: 1
    (np.array([1, 0]), 0), # Girdi: [1, 0] -> Hedef: 0
    (np.array([0, 1]), 0), # Girdi: [0, 1] -> Hedef: 0
    (np.array([0, 0]), 0), # Girdi: [0, 0] -> Hedef: 0
]

# --- 2. BAŞLANGIÇ AYARLARI (İLK BİLGİSİZLİK ANI) ---
# Ağırlıklar (a1, a2), her girdinin ne kadar "önemli" olduğunu belirler [cite: 168-170].
# Başlangıçta hücremiz cahil olduğu için ağırlıkları 0.0 yapıyoruz.
weights = np.array([0.0, 0.0])
bias = 0.0          # Hücrenin karar eşiğini ayarlayan yardımcı (sabit) değer.
ogrenme_hizi = 0.1  # Hücrenin her hatadan ne kadar büyük ders çıkaracağını belirler.

print("--- Yapay Hücrenin Öğrenme Serüveni Başlıyor ---")

# --- 3. EĞİTİM DÖNGÜSÜ (ÖĞRENME SÜRECİ) ---
# Hücre veriye bakacak, hata yapacak ve hatasını düzeltecek (Geri Yayılım) .
for epoch in range(20): 
    toplam_hata = 0
    for x, y_hedef in egitim_verisi:
        
        # MATEMATİKSEL MUTFAK: y = f(a1*x1 + a2*x2 + bias)
        # Her girdi kendi ağırlığıyla çarpılır ve toplanır.
        toplam_sinyal = np.dot(x, weights) + bias
        
        # KARAR ANI: Toplam sinyale bakıp 0 mı 1 mi diyeceğiz?
        tahmin = aktivasyon_f(toplam_sinyal)
        
        # HATA HESAPLAMA: Olması gereken (y_hedef) ile bizim dediğimiz (tahmin) farkı [cite: 199-201].
        hata = y_hedef - tahmin
        toplam_hata += abs(hata)
        
        # GERİ YAYILIM VE GÜNCELLEME (Backpropagation Ruhu)
        # Eğer hücre yanlış yaptıysa (hata != 0), ağırlıkları (a) biraz değiştiriyoruz [cite: 202-206].
        # Bu işlem, hücrenin bir dahaki sefere daha doğru tahmin yapmasını sağlar.
        weights += ogrenme_hizi * hata * x
        bias += ogrenme_hizi * hata
        
    if toplam_hata == 0:
        print(f"Tur {epoch+1}: Mükemmel! Hücre kuralları tamamen kavradı.")
        break
    else:
        print(f"Tur {epoch+1}: Hala kafası karışık... Toplam hata: {toplam_hata}")

# --- 4. TEST VE SONUÇ ---
print("\n--- Bakalım Hücremiz Ne Kadar Akıllanmış? ---")
for x, _ in egitim_verisi:
    # Ağırlıkların son haliyle karar veriyoruz
    hesaplanan_sinyal = np.dot(x, weights) + bias
    sonuc = aktivasyon_f(hesaplanan_sinyal)
    
    # Neden 1 veya 0 dediğini de teknik olarak görelim:
    aciklama = "1 (Ateşlendi)" if sonuc == 1 else "0 (Sessiz Kaldı)"
    print(f"Girdi: {x} -> Sinyal Gücü: {hesaplanan_sinyal:.1f} -> Karar: {aciklama}")

print(f"\nFinal Ağırlıkları (Hücrenin Tecrübesi): {weights}")
# Out:
# --- Yapay Hücrenin Öğrenme Serüveni Başlıyor ---
# Tur 1: Hala kafası karışık... Toplam hata: 1
# Tur 2: Hala kafası karışık... Toplam hata: 3
# Tur 3: Hala kafası karışık... Toplam hata: 2
# Tur 4: Hala kafası karışık... Toplam hata: 2
# Tur 5: Hala kafası karışık... Toplam hata: 3
# Tur 6: Hala kafası karışık... Toplam hata: 1
# Tur 7: Mükemmel! Hücre kuralları tamamen kavradı.
#
# --- Bakalım Hücremiz Ne Kadar Akıllanmış? ---
# Girdi: [1 1] -> Sinyal Gücü: 0.1 -> Karar: 1 (Ateşlendi)
# Girdi: [1 0] -> Sinyal Gücü: -0.1 -> Karar: 0 (Sessiz Kaldı)
# Girdi: [0 1] -> Sinyal Gücü: -0.0 -> Karar: 0 (Sessiz Kaldı)
# Girdi: [0 0] -> Sinyal Gücü: -0.2 -> Karar: 0 (Sessiz Kaldı)
#
# Final Ağırlıkları (Hücrenin Tecrübesi): [0.1 0.2]
